# %% [markdown]
# # **Regression Analysis**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import dataset
ep = pd.read_csv('../data/ep_speeches_populist_party.csv')
